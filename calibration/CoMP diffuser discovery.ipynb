# %%
import astropy.io.fits
import glob
import numpy
import matplotlib. pyplot as plt 
plt.rcParams['figure.figsize'] = [12, 8]

# %%
dataDir = "/hao/mahidata1/Data/CoMP/raw/20180404"
ftsList = glob.glob(dataDir+"/*FTS")
ftsList = ["20180404.083636.FTS","20180404.084025.FTS","20180404.084109.FTS","20180404.084149.FTS","20180404.084233.FTS","20180404.084709.FTS","20180404.084758.FTS","20180404.084842.FTS","20180404.084922.FTS","20180404.085006.FTS","20180404.085839.FTS","20180404.085928.FTS","20180404.090012.FTS","20180404.090052.FTS","20180404.090155.FTS"]


dataDir = "/hao/mahidata1/Data/CoMP/raw/20170404"
ftsList = glob.glob(dataDir+"/*FTS")
ftsL = """
20170404.083523.FTS
20170404.083603.FTS
20170404.083643.FTS
20170404.083724.FTS
20170404.083804.FTS
20170404.083844.FTS
20170404.083924.FTS
20170404.084004.FTS
20170404.084044.FTS
20170404.084124.FTS
20170404.084211.FTS
20170404.084252.FTS
20170404.084338.FTS
20170404.084439.FTS
20170404.084553.FTS
20170404.084633.FTS
20170404.084713.FTS
20170404.084753.FTS
20170404.084833.FTS
20170404.084913.FTS
20170404.084953.FTS
20170404.085033.FTS
20170404.085113.FTS
20170404.085153.FTS
20170404.085233.FTS
20170404.085313.FTS
20170404.085353.FTS
20170404.085441.FTS
20170404.085521.FTS
20170404.085608.FTS
20170404.085708.FTS
20170404.085822.FTS
20170404.085902.FTS
20170404.085942.FTS
20170404.090023.FTS
20170404.090103.FTS
20170404.090143.FTS
20170404.090223.FTS
20170404.090303.FTS
20170404.090343.FTS
20170404.090423.FTS"""
ftsList = [y for y in (x.strip() for x in ftsL.splitlines()) if y]
dataDir = "/hao/mahidata1/Data/CoMP/raw/20170404"
ftsList = glob.glob(dataDir+"/*FTS")

# %%
dataDir = "/hao/mahidata1/Data/CoMP/raw/20161214"
ftsList = glob.glob(dataDir+"/*FTS")
data = []
for fts in ftsList:
    with astropy.io.fits.open(fts) as hdul:
        for hdu in hdul:
            #print(hdu)
            if hdu.name == "PRIMARY":
               hdu.verify('fix')
               print(f"{fts}  {hdu.header['OBS_PLAN']}")

# %%
ftsL= """/hao/mahidata1/Data/CoMP/raw/20170721/20170721.103938.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170721/20170721.104040.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170721/20170721.104124.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170721/20170721.104204.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170721/20170721.104248.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170721/20170721.104811.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170721/20170721.104901.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170721/20170721.104945.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170721/20170721.105025.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170721/20170721.105109.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170721/20170721.105536.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170721/20170721.105638.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170721/20170721.105722.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170721/20170721.105802.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170721/20170721.105846.FTS  diffuser"""
ftsList20170721 = [y for y in (x.strip().split(" ")[0] for x in ftsL.splitlines()) if y]
ftsList20170721
#dataDir = "/hao/mahidata1/Data/CoMP/raw/20170721"
#ftsList = glob.glob(dataDir+"/*FTS")
# Out:
# ['/hao/mahidata1/Data/CoMP/raw/20170721/20170721.103938.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170721/20170721.104040.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170721/20170721.104124.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170721/20170721.104204.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170721/20170721.104248.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170721/20170721.104811.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170721/20170721.104901.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170721/20170721.104945.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170721/20170721.105025.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170721/20170721.105109.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170721/20170721.105536.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170721/20170721.105638.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170721/20170721.105722.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170721/20170721.105802.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170721/20170721.105846.FTS']

# %%
ftsL= """/hao/mahidata1/Data/CoMP/raw/20180330/20180330.115610.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180330/20180330.115659.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180330/20180330.115744.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180330/20180330.115824.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180330/20180330.115908.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180330/20180330.120905.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180330/20180330.120954.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180330/20180330.121039.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180330/20180330.121119.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180330/20180330.121202.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180330/20180330.121819.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180330/20180330.121909.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180330/20180330.121953.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180330/20180330.122033.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180330/20180330.122117.FTS  diffuser"""
ftsList20180330 = [y for y in (x.strip().split(" ")[0] for x in ftsL.splitlines()) if y]
ftsList20180330
#dataDir = "/hao/mahidata1/Data/CoMP/raw/20170721"
#ftsList = glob.glob(dataDir+"/*FTS")
# Out:
# ['/hao/mahidata1/Data/CoMP/raw/20180330/20180330.115610.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180330/20180330.115659.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180330/20180330.115744.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180330/20180330.115824.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180330/20180330.115908.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180330/20180330.120905.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180330/20180330.120954.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180330/20180330.121039.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180330/20180330.121119.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180330/20180330.121202.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180330/20180330.121819.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180330/20180330.121909.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180330/20180330.121953.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180330/20180330.122033.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180330/20180330.122117.FTS']

# %%
ftsL= """/hao/mahidata1/Data/CoMP/raw/20180404/20180404.082122.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180404/20180404.082219.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180404/20180404.082303.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180404/20180404.082343.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180404/20180404.083636.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180404/20180404.084025.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180404/20180404.084109.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180404/20180404.084149.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180404/20180404.084233.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180404/20180404.084709.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180404/20180404.084758.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180404/20180404.084842.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180404/20180404.084922.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180404/20180404.085006.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180404/20180404.085839.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180404/20180404.085928.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180404/20180404.090012.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180404/20180404.090052.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20180404/20180404.090155.FTS  diffuser"""
ftsList20180404 = [y for y in (x.strip().split(" ")[0] for x in ftsL.splitlines()) if y]
ftsList20180404
#dataDir = "/hao/mahidata1/Data/CoMP/raw/20170721"
#ftsList = glob.glob(dataDir+"/*FTS")
# Out:
# ['/hao/mahidata1/Data/CoMP/raw/20180404/20180404.082122.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180404/20180404.082219.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180404/20180404.082303.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180404/20180404.082343.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180404/20180404.083636.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180404/20180404.084025.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180404/20180404.084109.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180404/20180404.084149.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180404/20180404.084233.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180404/20180404.084709.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180404/20180404.084758.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180404/20180404.084842.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180404/20180404.084922.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180404/20180404.085006.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20180404/20180404.085839.FTS',
# ...

# %%
ftsL= """/hao/mahidata1/Data/CoMP/raw/20170719/20170719.100955.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.101057.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.101141.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.101221.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.101305.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.101505.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.101608.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.101652.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.101732.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.101816.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.102209.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.102259.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.102343.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.102423.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.102508.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.103112.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.103214.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.103258.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.103338.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.103422.FTS  diffuser
/hao/mahidata1/Data/CoMP/raw/20170719/20170719.103537.FTS  diffuser"""
ftsList20170719 = [y for y in (x.strip().split(" ")[0] for x in ftsL.splitlines()) if y]
ftsList20170719
# Out:
# ['/hao/mahidata1/Data/CoMP/raw/20170719/20170719.100955.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170719/20170719.101057.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170719/20170719.101141.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170719/20170719.101221.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170719/20170719.101305.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170719/20170719.101505.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170719/20170719.101608.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170719/20170719.101652.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170719/20170719.101732.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170719/20170719.101816.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170719/20170719.102209.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170719/20170719.102259.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170719/20170719.102343.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170719/20170719.102423.FTS',
#  '/hao/mahidata1/Data/CoMP/raw/20170719/20170719.102508.FTS',
# ...

# %%
data20170719 = []
for ftsG in ftsList20170719:
    fts = ftsG
    with astropy.io.fits.open(fts) as hdul:
        for hdu in hdul:
            if hdu.name != "PRIMARY":
                data20170719.append(numpy.median(hdu.data))
            
plt.plot(data20170719)
plt.title("2017 07 19")
#plt.axis([0, 3500, 2050, 2120])
plt.show()

# %%
for ftsG in ftsList20170719:
    fts = ftsG
    with astropy.io.fits.open(fts) as hdul:
        for hdu in hdul:
            if hdu.name == "PRIMARY":
                hdu.verify('fix')
                print(f"{fts.split('/')[-1]}  {hdu.header['OBS_ID']}")
# Out:
# 20170719.100955.FTS  dark_250ms
# 20170719.101057.FTS  1074_QU_11_250ms_2be
# 20170719.101141.FTS  1074_V_5_250ms_2beam
# 20170719.101221.FTS  1074_QU_11_250ms_2be
# 20170719.101305.FTS  1074_V_5_250ms_2beam
# 20170719.101505.FTS  dark_250ms
# 20170719.101608.FTS  1074_QU_11_250ms_2be
# 20170719.101652.FTS  1074_V_5_250ms_2beam
# 20170719.101732.FTS  1074_QU_11_250ms_2be
# 20170719.101816.FTS  1074_V_5_250ms_2beam
# 20170719.102209.FTS  dark_250ms
# 20170719.102259.FTS  1074_QU_11_250ms_2be
# 20170719.102343.FTS  1074_V_5_250ms_2beam
# 20170719.102423.FTS  1074_QU_11_250ms_2be
# 20170719.102508.FTS  1074_V_5_250ms_2beam
# 20170719.103112.FTS  dark_250ms
# 20170719.103214.FTS  1074_QU_11_250ms_2be
# 20170719.103258.FTS  1074_V_5_250ms_2beam
# 20170719.103338.FTS  1074_QU_11_250ms_2be
# 20170719.103422.FTS  1074_V_5_250ms_2beam
# 20170719.103537.FTS  dark_250ms

# %% [markdown]
# 2017 07 19
# First start at the diffuser test had a bad cookbook.  Put the opal in while the badder filter was in oops.
#
# But during the second run we started getting some clouds cover during the second set of opal flats.
#
# May try again with this test later in the week or on Monday
#
# This contains 3 diffuser.cbk sequences:
# 0->~400 sequence 1 aborted earily
# ~400->~1550 Sequence 2 a complete sequence
# ~1550-> start of seqeunce 3 just a dark

# %%
data20170721 = []
for ftsG in ftsList20170721:
    fts = ftsG
    with astropy.io.fits.open(fts) as hdul:
        for hdu in hdul:
            if hdu.name != "PRIMARY":
                data20170721.append(numpy.median(hdu.data))
            
plt.plot(data20170721)
plt.title("2017 07 21")
#plt.axis([0, 3500, 2050, 2120])
plt.show()

# %%
for ftsG in ftsList20170721:
    fts = ftsG
    with astropy.io.fits.open(fts) as hdul:
        for hdu in hdul:
            if hdu.name == "PRIMARY":
                hdu.verify('fix')
                print(f"{fts.split('/')[-1]}  {hdu.header['OBS_ID']}")
# Out:
# 20170721.103938.FTS  dark_250ms
# 20170721.104040.FTS  1074_QU_11_250ms_2be
# 20170721.104124.FTS  1074_V_5_250ms_2beam
# 20170721.104204.FTS  1074_QU_11_250ms_2be
# 20170721.104248.FTS  1074_V_5_250ms_2beam
# 20170721.104811.FTS  dark_250ms
# 20170721.104901.FTS  1074_QU_11_250ms_2be
# 20170721.104945.FTS  1074_V_5_250ms_2beam
# 20170721.105025.FTS  1074_QU_11_250ms_2be
# 20170721.105109.FTS  1074_V_5_250ms_2beam
# 20170721.105536.FTS  dark_250ms
# 20170721.105638.FTS  1074_QU_11_250ms_2be
# 20170721.105722.FTS  1074_V_5_250ms_2beam
# 20170721.105802.FTS  1074_QU_11_250ms_2be
# 20170721.105846.FTS  1074_V_5_250ms_2beam

# %% [markdown]
# For the diffuser test the Badder t=2.6e-4@1074.6nm was installed in the beam.  There is very little signal when the Badder ND and Opal are in the beam, in the realtime displays it is impossible to tell the location of the solar disk.
#
# Notes on image timming.
# Start diffuser test.  With non-functionning diffuser header says OPAL is in but this is incorrect.
# 122250.FTS->122601.FTS Standard darks and bad flats (opal out)
# 123825.FTS->124137.FTS Badder in beam occulter out, standard darks and bad flats
# 124738.FTS->125049.FTS Standard darks and bad flats (opal out)
# OPAL FIXED
# 130804.FTS->131115.FTS Standard darks and flats
# 132105.FTS->132415.FTS Badder in beam occulter out, standard darks and flats
# Badder removed end of test.
#
# One sequence

# %%
data20180404 = []
for ftsG in ftsList20180404:
    fts = ftsG
    with astropy.io.fits.open(fts) as hdul:
        for hdu in hdul:
            if hdu.name != "PRIMARY":
                data20180404.append(numpy.median(hdu.data))
            
plt.plot(data20180404)
plt.title("2018 04 04")
#plt.axis([0, 3500, 2050, 2120])
plt.show()

# %%
for ftsG in ftsList20180404:
    fts = ftsG
    with astropy.io.fits.open(fts) as hdul:
        for hdu in hdul:
            if hdu.name == "PRIMARY":
                hdu.verify('fix')
                print(f"{fts.split('/')[-1]}  {hdu.header['OBS_ID']}")
# Out:
# 20180404.082122.FTS  dark_250ms
# 20180404.082219.FTS  1074_QU_11_250ms_2be
# 20180404.082303.FTS  1074_V_5_250ms_2beam
# 20180404.082343.FTS  1074_QU_11_250ms_2be
# 20180404.083636.FTS  dark_250ms
# 20180404.084025.FTS  1074_QU_11_250ms_2be
# 20180404.084109.FTS  1074_V_5_250ms_2beam
# 20180404.084149.FTS  1074_QU_11_250ms_2be
# 20180404.084233.FTS  1074_V_5_250ms_2beam
# 20180404.084709.FTS  dark_250ms
# 20180404.084758.FTS  1074_QU_11_250ms_2be
# 20180404.084842.FTS  1074_V_5_250ms_2beam
# 20180404.084922.FTS  1074_QU_11_250ms_2be
# 20180404.085006.FTS  1074_V_5_250ms_2beam
# 20180404.085839.FTS  dark_250ms
# 20180404.085928.FTS  1074_QU_11_250ms_2be
# 20180404.090012.FTS  1074_V_5_250ms_2beam
# 20180404.090052.FTS  1074_QU_11_250ms_2be
# 20180404.090155.FTS  1074_V_5_250ms_2beam

# %% [markdown]
# It was noted that during
# The 1074_V_5_250ms_2beam.rcp 08:41:09 opal data we noted a cloud that passed over with less than 5% drop in sgs
# The 1074_QU_11_250ms_2beam.rcp 08:47:58 badder filter data had a passing cloud that had a much smaller drop in the sgs signal
# The 1074_V_5_250ms_2beam.rcp 08:50:05 badder filter data had a passing cloud with no percieved drop in the sgs signal.
#
# 2 Sequences:
# 0->~320 Sequence 1 aborted
# ~320->1500 Sequence 2

# %%
data20180330 = []
for ftsG in ftsList20180330:
    fts = ftsG
    with astropy.io.fits.open(fts) as hdul:
        for hdu in hdul:
            if hdu.name != "PRIMARY":
                data20180330.append(numpy.median(hdu.data))
            
plt.plot(data20180330)
plt.title("2018 03 30")
#plt.axis([0, 3500, 2050, 2120])
plt.show()

# %%
for ftsG in ftsList20180330:
    fts = ftsG
    with astropy.io.fits.open(fts) as hdul:
        for hdu in hdul:
            if hdu.name == "PRIMARY":
                hdu.verify('fix')
                print(f"{fts.split('/')[-1]}  {hdu.header['OBS_ID']}")
# Out:
# 20180330.115610.FTS  dark_250ms
# 20180330.115659.FTS  1074_QU_11_250ms_2be
# 20180330.115744.FTS  1074_V_5_250ms_2beam
# 20180330.115824.FTS  1074_QU_11_250ms_2be
# 20180330.115908.FTS  1074_V_5_250ms_2beam
# 20180330.120905.FTS  dark_250ms
# 20180330.120954.FTS  1074_QU_11_250ms_2be
# 20180330.121039.FTS  1074_V_5_250ms_2beam
# 20180330.121119.FTS  1074_QU_11_250ms_2be
# 20180330.121202.FTS  1074_V_5_250ms_2beam
# 20180330.121819.FTS  dark_250ms
# 20180330.121909.FTS  1074_QU_11_250ms_2be
# 20180330.121953.FTS  1074_V_5_250ms_2beam
# 20180330.122033.FTS  1074_QU_11_250ms_2be
# 20180330.122117.FTS  1074_V_5_250ms_2beam

# %% [markdown]
# The diffuser/opal test started at 21:55UT and ran without incident (other then the degrading weather)
#  Volcanic smog/so2 was tasted in the air within about 30 minutes of the start of the good polarization calibration (these data taken before diffuser test), with obvious cloud textures passing over the site in the building camera
#
#  1 sequence

# %%
data20180330IQ = []
for ftsG in ftsList20180330:
    fts = ftsG
    with astropy.io.fits.open(fts) as hdul:
        for hdu in hdul:
            if hdu.name != "PRIMARY":
                if hdu.header['POLSTATE'] == "I+Q" and hdu.header['BEAM']==1:
                    data20180330IQ.append(numpy.median(hdu.data))
            
plt.plot(data20180330IQ)
plt.title("2018 03 30 I + Q Beam=1")
#plt.axis([0, 3500, 2050, 2120])
plt.show()

# %%
with astropy.io.fits.open('/hao/mahidata1/Data/CoMP/raw/20180330/20180330.115744.FTS') as testData:
    plt.imshow(testData[20].data)
    plt.title("2018 03 30 Diffuser image corona image")

# %%
with astropy.io.fits.open('/hao/mahidata1/Data/CoMP/raw/20180330/20180330.121039.FTS') as testData:
    plt.imshow(testData[20].data)
    plt.title("2018 03 30 ND filter disk image")

# %%
data20170721 = []
for ftsG in ftsList20170721 :
    fts = ftsG
    with astropy.io.fits.open(fts) as hdul:
        for hdu in hdul:
            if hdu.name == "PRIMARY":
                if hdu.header["COVER"] == 1:
                    if hdu.header["OPAL"] ==1:
                        print(f"{fts} diffuser")
                    else:
                        print(f"{fts} ND")
               #break
            if hdu.name != "PRIMARY":
                if hdu.header["DATATYPE"] == "DATA":
                    data20170721.append(numpy.median(hdu.data))
            
plt.plot(data20170721 )
plt.title("2017 07 21")
#plt.axis([0, 3500, 2050, 2120])
plt.show()
# Out:
# /hao/mahidata1/Data/CoMP/raw/20170721/20170721.104040.FTS diffuser
# /hao/mahidata1/Data/CoMP/raw/20170721/20170721.104124.FTS diffuser
# /hao/mahidata1/Data/CoMP/raw/20170721/20170721.104204.FTS diffuser
# /hao/mahidata1/Data/CoMP/raw/20170721/20170721.104248.FTS diffuser
# /hao/mahidata1/Data/CoMP/raw/20170721/20170721.104901.FTS ND
# /hao/mahidata1/Data/CoMP/raw/20170721/20170721.104945.FTS ND
# /hao/mahidata1/Data/CoMP/raw/20170721/20170721.105025.FTS ND
# /hao/mahidata1/Data/CoMP/raw/20170721/20170721.105109.FTS ND
# /hao/mahidata1/Data/CoMP/raw/20170721/20170721.105638.FTS diffuser
# /hao/mahidata1/Data/CoMP/raw/20170721/20170721.105722.FTS diffuser
# /hao/mahidata1/Data/CoMP/raw/20170721/20170721.105802.FTS diffuser
# /hao/mahidata1/Data/CoMP/raw/20170721/20170721.105846.FTS diffuser

# %%
testData[0].header
# Out:
# SIMPLE  =                    T /
# BITPIX  =                   16 / BITS PER PIXEL
# NAXIS   =                    0 / NUMBER OF AXES (2)
# NAXIS1  =                 1024 / XDIM (PIXELS)
# NAXIS2  =                 1024 / YDIM (PIXELS)
# EXTEND  =                    T / EXTENTIONS POSSIBLE
# OBSERVER=               'MLSO' /
# DATE_OBS=          '3/30/2018' / DATE OF OBSERVATION
# TIME_OBS=        '11:57:43 AM' / TIME OF OBSERVATION
# ORIGIN  =           'HAO/NCAR' /
# INSTRUME=               'COMP' / CORONAL MULTICHANNEL POLARIMETER
# TELESCOP=     '20 CM ONE SHOT' /
# LOCATION=               'MLSO' /
# TNELNGTH=                    0 / DURATION OF TNE PULSE (MS)
# TUNEDLAY=                  200 / TUNER DELAY (MS)
# H-OCCULT=               794992 / HORIZONTAL OCCULTER POSITION
# V-OCCULT=                83500 / VERTICAL OCCULTER POSITION
# OCCULTER=                   31 / OCCULTER SIZE
# FOCUS   =                24700 / FOCUS STAGE POSITION
# ...
